# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Proyecto Final Udemy/scripts
# Out:
# /content/drive/MyDrive/Colab Notebooks/Proyecto Final Udemy/scripts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ApylabradosModule
from ApylabradosModule import Pawns, Word, Dictionary, FrequencyTable, Board

# %%
ApylabradosModule.startGame()

while not ApylabradosModule.end and ApylabradosModule.bag_of_pawns.getTotalPawns() > 0:
  ApylabradosModule.showOptions() # Mostrar opciones disponibles

if ApylabradosModule.bag_of_pawns.getTotalPawns() <= 0:
  print("¡Te has quedado sin fichas en la bolsa!")
  print("Fin del juego")

print("¡Enhorabuena! Has conseguido {} puntos en esta partida".format(Board.score))
# Out:
# ¡¡¡ Bienvenido a Apylabrados !!!
# ¡ Juega con palabras y gana tantos puntos como puedas !
# Instrucciones del juego:
#     Introduce las palabras en MAYÚSCULAS
#     La primera palabra debe pasar siempre por la casilla central
#     Salvo la primera palabra, debes formar el resto de palabras aprovechando al menos una ficha ya situada sobre el tablero
#     Solamente hay dos posibles direcciones para colocar las palabras: V (vertical) y H (horizontal)
# ...
# ¿Qué deseas hacer?
# Para continuar, introduce ENTERWORD
# Para consultar tus fichas, introduce MYPAWNS
# Para consultar tus puntos actuales, introduce MYSCORE
# Para consultar los puntos de cada ficha, introduce PAWNSPOINTS
# Para obtener ayuda con las posibles palabras a formar con tus fichas, introduce HELPWORD
# Para consultar la leyenda de las casillas del tablero, introduce HELPLEGEND
# Para salir del juego, introduce QUITGAME
# helplegend
# ¿Qué deseas hacer? (Introduce SHOWHELP para ver las diferentes opciones)
# helpword
# ...
